# %%
import numpy as np
import pandas as pd

np.random.seed(100)
ser = pd.Series(np.random.randint(1, 5, [12]))

# %% [markdown]
# Giữ nguyên hai phần tử có tần suất cao nhất (top 2 most frequent items) và thay thế tất cả các phần tử còn lại bằng giá trị 'Other'

# %%
so_lan_xuat_hien = ser.value_counts()
hai_gia_tri_cao_nhat = so_lan_xuat_hien.index[:2]

ser_copy = ser.copy()
ser_copy[~ser_copy.isin(hai_gia_tri_cao_nhat)] = 'Other'

print(ser_copy)
# Out:
# 0         1
# 1         1
# 2         4
# 3         4
# 4         4
# 5         4
# 6         1
# 7     Other
# 8     Other
# 9         1
# 10    Other
# 11    Other
# dtype: object
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4180\2757728808.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   ser_copy[~ser_copy.isin(hai_gia_tri_cao_nhat)] = 'Other'
