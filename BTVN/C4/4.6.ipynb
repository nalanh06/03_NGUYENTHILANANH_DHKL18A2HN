# %%
import numpy as np 
import pandas as pd

ser = pd.Series(np.take(list('abcdefgh'), np.random.randint(8, size = 30)))

# %% [markdown]
# Giải thích ý nghĩa của đoạn code: Đoạn code này tạo ra một đối tượng Series có 30 phần tử, mỗi phần tử là một ký tự được chọn ngẫu nhiên từ danh sách 'a' đến 'h'. Đối tượng Series này sau đó có thể được sử dụng cho các phân tích hoặc các thao tác xử lý dữ liệu khác Pandas.

# %%
# Tính số lần xất hiện của mỗi giá trị duy nhất trong ser
result = ser.value_counts()
print(result)
# Out:
# f    10
# c     4
# a     3
# b     3
# e     3
# h     3
# d     2
# g     2
# Name: count, dtype: int64
